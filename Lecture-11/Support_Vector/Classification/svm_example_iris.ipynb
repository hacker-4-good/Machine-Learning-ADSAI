# %%
import pandas as pd
from sklearn.datasets import load_iris
# Load Wine dataset
wine = load_iris()
X = wine.data
y = wine.target
df = pd.DataFrame(X, columns=wine.feature_names)
df['target'] = y
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
from sklearn.datasets import load_iris
import matplotlib.pyplot as plt
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import numpy as np
# Load the Iris dataset
data = load_iris()
X = data.data[:, :2]  # Use only the first two features for visualization
y = data.target
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
   X, y, test_size=0.3, random_state=42
)
# Build the SVM model with RBF kernel
svm = SVC(kernel="poly", gamma=0.5, C=1.0)
# Train the model
svm.fit(X_train, y_train)
# Plot Decision Boundary
DecisionBoundaryDisplay.from_estimator(
   svm,
   X_train,
   response_method="predict",
   cmap=plt.cm.Spectral,
   alpha=0.8,
   xlabel=data.feature_names[0],  # Sepal length (cm)
   ylabel=data.feature_names[1],  # Sepal width (cm)
)
# Scatter plot of training data
plt.scatter(
   X_train[:, 0],
   X_train[:, 1],
   c=y_train,
   s=40,
   edgecolors="k"
)
plt.title("SVM Decision Boundary (using 2 Iris features)")
plt.show()
# Evaluate the model
y_pred = svm.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
''' Output -
Accuracy: 0.80
'''
# Out:
# Accuracy: 0.78
# ' Output -\nAccuracy: 0.80\n'
